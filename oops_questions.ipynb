# %% [markdown]
# # OOPS Questions
#
# 1. What is Object-Oriented Programming (OOP)?
#    - OOP is a programming paradigm that organizes code around objects — which bundle data (attributes) and behavior (methods)
#
# 2. What is a class in OOP?
#    - A class is a blueprint or template for creating objects.
# It defines the attributes (variables) and methods (functions) that characterize the object.
#
# 3. What is an object in OOP?
#    - An object is an instance of a class.
# It represents a specific entity created from the class blueprint.
#
# 4. What is the difference between abstraction and encapsulation.
#    - Abstraction - Hides complex implementation details and shows only essential features.
#     - Encapsulation - Bundles data and methods into a single unit and restricts direct access to internal data.
#
# 5. What are dunder methods in Python.
#    - “Dunder” = Double Underscore methods (a.k.a magic methods) that start and end with __.
# They define special behaviors in classes.
#
#    Examples:
#
#    __init__→ Constructor
#
#    __str__ → String representation
#
#    __add__ → Defines behavior for + operator
#
#    __call__ → Makes an object callable
#
# 6. Explain the concept of inheritance in OOP
#    - Inheritance allows a class (child/subclass) to derive properties and methods from another class (parent/base).
#
# 7. What is polymorphism in OOP
#    - Polymorphism means “many forms.”
# It allows different classes to use methods with the same name but different implementations.
#
# 8. How is encapsulation achieved in Python
#    - Encapsulation is achieved using:
#
#    Private variables: _variable (protected) and __variable (private)
#
#    Getter and setter methods
#
#    Property decorators
#
# 9. What is a constructor in Python
#    - The __init__() method initializes an object’s attributes when it’s created
#
# 10. What are class and static methods in Python
#     - Class method (@classmethod): Works with the class itself.
#     - Static method (@staticmethod): Works independently of both instance and class.
#
# 11. What is method overloading in Python.
#     - Python doesn’t support true method overloading (like Java).
# You can simulate it by using default parameters or *args and **kwargs.
#
# 12. What is method overriding in OOP.
#     - Occurs when a child class provides a new implementation for a method inherited from the parent class.
#
# 13. What is a property decorator in Python.
#     - @property allows you to use methods like attributes — useful for encapsulation.
#
# 14. Why is polymorphism important in OOP
#     - It enables flexibility, code reusability, and the ability to use different objects through a common interface, improving extensibility.
#
# 15. What is an abstract class in Python.
#     - An abstract class defines methods that must be implemented by subclasses.
# Use the abc module.
#
# 16. What are the advantages of OOP.
#     - Reusability via inheritance
#
#     - Modularity
#
#     - Maintainability
#
#     - Data hiding and abstraction
#
#     - Easier debugging and testing
#
# 17. What is the difference between a class variable and an instance variable.
#     - Class variable - Shared across all instances
#       Ex. Car.wheels = 4
#
# 18. What is multiple inheritance in Python.
#     - When a class inherits from more than one parent class.
#
# 19. Explain the purpose of ‘’__str__’ and ‘__repr__’ ‘ methods in Python.
#     - __str__: User-friendly string (used by print())
#
#     - __repr__: Developer representation (used in debugging)
#
# 20. What is the significance of the ‘super()’ function in Python.
#     - super() calls methods from a parent class, typically used to initialize the base class.
#
# 21. What is the significance of the __del__ method in Python.
#     - Called when an object is about to be destroyed (like a destructor).
# Used for cleanup.
#
# 22. What is the difference between @staticmethod and @classmethod in Python.
#     - @staticmethod - Defines a method that does not depend on class or instance data, No special first parameter (like self or cls).
#     - @classmethod - Defines a method that operates on the class itself, not on an instance,Takes cls as the first parameter, representing the class.
#
# 23. How does polymorphism work in Python with inheritance
#     - When subclasses override parent methods, the child’s version is used at runtime.
#
# 24. What is method chaining in Python OOP
#     - Returning self from a method allows multiple method calls in one line.
#
#      Ex.
#      class Builder:
#
#      def start(self):
#
#         print("Start")
#
#         return self
#
# 25. What is the purpose of the __call__ method in Python.
#     - Makes an object callable like a function.
#
#      class Adder:
#
#      def __call__(self, a, b):
#
#         return a + b
#
#      add = Adder()
#
#      print(add(3, 5))

# %% [markdown]
# # Practical Questions
#
# 1. Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog
# that overrides the speak() method to print "Bark!"?

# %%
class Animal:
    def speak(self):
        print("The animal makes a sound.")

class Dog(Animal):
    def speak(self):
        print("Bark!")

a = Animal()
a.speak()

d = Dog()
d.speak()
# Out:
# The animal makes a sound.
# Bark!

# %% [markdown]
# 2. Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle
# from it and implement the area() method in both.

# %%
from abc import ABC, abstractmethod
import math

class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return math.pi * self.radius ** 2

class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

c = Circle(5)
r = Rectangle(4, 6)

print("Circle area:", c.area())
print("Rectangle area:", r.area())
# Out:
# Circle area: 78.53981633974483
# Rectangle area: 24

# %% [markdown]
# 3.  Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car
# and further derive a class ElectricCar that adds a battery attribute.

# %%
class Vehicle:
    def __init__(self, vehicle_type):
        self.vehicle_type = vehicle_type

class Car(Vehicle):
    def __init__(self, vehicle_type, brand):
        super().__init__(vehicle_type)
        self.brand = brand

class ElectricCar(Car):
    def __init__(self, vehicle_type, brand, battery_capacity):
        super().__init__(vehicle_type, brand)
        self.battery_capacity = battery_capacity

e_car = ElectricCar("Four-wheeler", "Tesla", "85 kWh")

print(f"Type: {e_car.vehicle_type}, Brand: {e_car.brand}, Battery: {e_car.battery_capacity}")
# Out:
# Type: Four-wheeler, Brand: Tesla, Battery: 85 kWh

# %% [markdown]
# 4. . Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes
# Sparrow and Penguin that override the fly() method.

# %%
class Bird:
    def fly(self):
        print("Some birds can fly.")

class Sparrow(Bird):
    def fly(self):
        print("Sparrow flies high in the sky!")

class Penguin(Bird):
    def fly(self):
        print("Penguins cannot fly, but they swim well!")

birds = [Sparrow(), Penguin()]

for bird in birds:
    bird.fly()
# Out:
# Sparrow flies high in the sky!
# Penguins cannot fly, but they swim well!

# %% [markdown]
# 5. Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes
# balance and methods to deposit, withdraw, and check balance.

# %%
class BankAccount:
    def __init__(self, balance=0):
        self.__balance = balance

    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
            print(f"Deposited: ${amount}")
        else:
            print("Deposit amount must be positive.")

    def withdraw(self, amount):
        if 0 < amount <= self.__balance:
            self.__balance -= amount
            print(f"Withdrew: ${amount}")
        else:
            print("Insufficient funds or invalid amount.")

    def get_balance(self):
        print(f"Current Balance: ${self.__balance}")

account = BankAccount(100)
account.deposit(50)
account.withdraw(30)
account.get_balance()
# Out:
# Deposited: $50
# Withdrew: $30
# Current Balance: $120

# %% [markdown]
# 6. Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar
# and Piano that implement their own version of play().

# %%
class Instrument:
    def play(self):
        print("Playing an instrument.")

class Guitar(Instrument):
    def play(self):
        print("Strumming the guitar 🎸")

class Piano(Instrument):
    def play(self):
        print("Playing the piano 🎹")

instruments = [Guitar(), Piano()]

for instrument in instruments:
    instrument.play()
# Out:
# Strumming the guitar 🎸
# Playing the piano 🎹

# %% [markdown]
# 7. Create a class MathOperations with a class method add_numbers() to add two numbers and a static
# method subtract_numbers() to subtract two numbers.

# %%
class MathOperations:
    @classmethod
    def add_numbers(cls, a, b):
        return a + b

    @staticmethod
    def subtract_numbers(a, b):
        return a - b

print("Addition:", MathOperations.add_numbers(10, 5))
print("Subtraction:", MathOperations.subtract_numbers(10, 5))
# Out:
# Addition: 15
# Subtraction: 5

# %% [markdown]
# 8.  Implement a class Person with a class method to count the total number of persons created.

# %%
class Person:
    count = 0

    def __init__(self, name):
        self.name = name
        Person.count += 1

    @classmethod
    def total_persons(cls):
        return cls.count

p1 = Person("Alice")
p2 = Person("Bob")
p3 = Person("Charlie")

print("Total persons created:", Person.total_persons())
# Out:
# Total persons created: 3

# %% [markdown]
# 9.  Write a class Fraction with attributes numerator and denominator. Override the str method to display the
# fraction as "numerator/denominator".

# %%
class Fraction:
    def __init__(self, numerator, denominator):
        self.numerator = numerator
        self.denominator = denominator

    def __str__(self):
        return f"{self.numerator}/{self.denominator}"

f = Fraction(3, 4)
print(f)
# Out:
# 3/4

# %% [markdown]
# 10. Demonstrate operator overloading by creating a class Vector and overriding the add method to add two
# vectors.

# %%
class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __add__(self, other):
        return Vector(self.x + other.x, self.y + other.y)

    def __str__(self):
        return f"Vector({self.x}, {self.y})"

v1 = Vector(2, 3)
v2 = Vector(4, 1)
v3 = v1 + v2
print(v3)
# Out:
# Vector(6, 4)

# %% [markdown]
# 11. Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is
# {name} and I am {age} years old."

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")

p = Person("David", 25)
p.greet()
# Out:
# Hello, my name is David and I am 25 years old.

# %% [markdown]
# 12.  Implement a class Student with attributes name and grades. Create a method average_grade() to compute
# the average of the grades.

# %%
class Student:
    def __init__(self, name, grades):
        self.name = name
        self.grades = grades

    def average_grade(self):
        return sum(self.grades) / len(self.grades)

s = Student("Alice", [85, 90, 88])
print(f"{s.name}'s average grade: {s.average_grade():.2f}")
# Out:
# Alice's average grade: 87.67

# %% [markdown]
# 13.  Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the
# area.

# %%
class Rectangle:
    def __init__(self):
        self.length = 0
        self.width = 0

    def set_dimensions(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

rect = Rectangle()
rect.set_dimensions(5, 3)
print("Area of rectangle:", rect.area())
# Out:
# Area of rectangle: 15

# %% [markdown]
# 14. Create a class Employee with a method calculate_salary() that computes the salary based on hours worked
# and hourly rate. Create a derived class Manager that adds a bonus to the salary

# %%
class Employee:
    def __init__(self, name, hours_worked, hourly_rate):
        self.name = name
        self.hours_worked = hours_worked
        self.hourly_rate = hourly_rate

    def calculate_salary(self):
        return self.hours_worked * self.hourly_rate

class Manager(Employee):
    def __init__(self, name, hours_worked, hourly_rate, bonus):
        super().__init__(name, hours_worked, hourly_rate)
        self.bonus = bonus

    def calculate_salary(self):
        base_salary = super().calculate_salary()
        return base_salary + self.bonus

emp = Employee("John", 40, 20)
mgr = Manager("Sarah", 45, 30, 500)

print(f"{emp.name}'s salary: ${emp.calculate_salary()}")
print(f"{mgr.name}'s salary (with bonus): ${mgr.calculate_salary()}")
# Out:
# John's salary: $800
# Sarah's salary (with bonus): $1850

# %% [markdown]
# 15.  Create a class Product with attributes name, price, and quantity. Implement a method total_price() that
# calculates the total price of the product.

# %%
class Product:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity

    def total_price(self):
        return self.price * self.quantity

p = Product("Laptop", 1200, 2)
print(f"Total price for {p.name}: ${p.total_price()}")
# Out:
# Total price for Laptop: $2400

# %% [markdown]
# 16.  Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that
# implement the sound() method.

# %%
from abc import ABC, abstractmethod

class Animal(ABC):
    @abstractmethod
    def sound(self):
        pass

class Cow(Animal):
    def sound(self):
        print("Moo!")

class Sheep(Animal):
    def sound(self):
        print("Baa!")

animals = [Cow(), Sheep()]
for a in animals:
    a.sound()
# Out:
# Moo!
# Baa!

# %% [markdown]
# 17. . Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that
# returns a formatted string with the book's details.

# %%
class Book:
    def __init__(self, title, author, year_published):
        self.title = title
        self.author = author
        self.year_published = year_published

    def get_book_info(self):
        return f"'{self.title}' by {self.author} ({self.year_published})"

book = Book("1984", "George Orwell", 1949)
print(book.get_book_info())
# Out:
# '1984' by George Orwell (1949)

# %% [markdown]
# 18. Create a class House with attributes address and price. Create a derived class Mansion that adds an
# attribute number_of_rooms.

# %%
class House:
    def __init__(self, address, price):
        self.address = address
        self.price = price

class Mansion(House):
    def __init__(self, address, price, number_of_rooms):
        super().__init__(address, price)
        self.number_of_rooms = number_of_rooms

m = Mansion("123 Palm Street", 2500000, 12)
print(f"Mansion at {m.address} costs ${m.price} and has {m.number_of_rooms} rooms.")
# Out:
# Mansion at 123 Palm Street costs $2500000 and has 12 rooms.
